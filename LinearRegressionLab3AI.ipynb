# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
DATASET_PATH = 'https://raw.githubusercontent.com/mdiannna/Labs_UTM_AI/main/Lab3/apartmentComplexData.txt'
COLUMN_NAMES_FULL = ['col1', 'col2', 'complexAge', 'totalRooms', 'totalBedrooms', 'complexInhabitants', 'apartmentsNr', 'col8', 'medianCompexValue']
# The model should predict the column 'medianCompexValue'

# %%
df = pd.read_csv(DATASET_PATH, names=COLUMN_NAMES_FULL)
df.head()
# Out:
#      col1   col2  complexAge  totalRooms  totalBedrooms  complexInhabitants  \
# 0 -122.23  37.88        41.0       880.0          129.0               322.0
# 1 -122.22  37.86        21.0      7099.0         1106.0              2401.0
# 2 -122.24  37.85        52.0      1467.0          190.0               496.0
# 3 -122.25  37.85        52.0      1274.0          235.0               558.0
# 4 -122.25  37.85        52.0      1627.0          280.0               565.0
#
#    apartmentsNr    col8  medianCompexValue
# 0         126.0  8.3252           452600.0
# 1        1138.0  8.3014           358500.0
# 2         177.0  7.2574           352100.0
# 3         219.0  5.6431           341300.0
# 4         259.0  3.8462           342200.0

# %%
df.describe()
# Out:
#                col1          col2    complexAge    totalRooms  totalBedrooms  \
# count  20640.000000  20640.000000  20640.000000  20640.000000   20640.000000
# mean    -119.569704     35.631861     28.639486   2635.763081     537.898014
# std        2.003532      2.135952     12.585558   2181.615252     421.247906
# min     -124.350000     32.540000      1.000000      2.000000       1.000000
# 25%     -121.800000     33.930000     18.000000   1447.750000     295.000000
# 50%     -118.490000     34.260000     29.000000   2127.000000     435.000000
# 75%     -118.010000     37.710000     37.000000   3148.000000     647.000000
# max     -114.310000     41.950000     52.000000  39320.000000    6445.000000
#
#        complexInhabitants  apartmentsNr          col8  medianCompexValue
# count        20640.000000  20640.000000  20640.000000       20640.000000
# mean          1425.476744    499.539680      3.870671      206855.816909
# std           1132.462122    382.329753      1.899822      115395.615874
# min              3.000000      1.000000      0.499900       14999.000000
# 25%            787.000000    280.000000      2.563400      119600.000000
# 50%           1166.000000    409.000000      3.534800      179700.000000
# 75%           1725.000000    605.000000      4.743250      264725.000000
# max          35682.000000   6082.000000     15.000100      500001.000000

# %%
## Show data distributions
df.hist(bins=10, figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'apartmentsNr'}>,
#         <AxesSubplot:title={'center':'col1'}>,
#         <AxesSubplot:title={'center':'col2'}>],
#        [<AxesSubplot:title={'center':'col8'}>,
#         <AxesSubplot:title={'center':'complexAge'}>,
#         <AxesSubplot:title={'center':'complexInhabitants'}>],
#        [<AxesSubplot:title={'center':'medianCompexValue'}>,
#         <AxesSubplot:title={'center':'totalBedrooms'}>,
#         <AxesSubplot:title={'center':'totalRooms'}>]], dtype=object)

# %%
## medianComplexValue column is not balanced

# %% [markdown]
# ## Some other plots

# %%
# this might take some time to execute

fig, axs = plt.subplots(ncols=4, nrows=2)
# set figure size
fig.set_figheight(15)
fig.set_figwidth(40)

i = 0
j = 0

for col in COLUMN_NAMES_FULL:
  if col!='medianCompexValue':
    sns.regplot(data=df, x=col, y='medianCompexValue', ax=axs[i % 2][j % 4])
    j+=1
    if j==4:
      i+=1

# %% [markdown]
# ## Correlations

# %% [markdown]
# ### Compute and show the correlation matrix

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row0_col2 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row0_col3 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row0_col4 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row0_col5 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row0_col6 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row0_col7 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row0_col8 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row1_col2 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row1_col3 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row1_col4 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row1_col5 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row1_col6 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row1_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row2_col0 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row2_col1 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row2_col8 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row3_col0 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row3_col1 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row3_col4 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row3_col5 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row3_col6 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row3_col7 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row3_col8 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row4_col0 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row4_col1 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row4_col2 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row4_col3 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row4_col5 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row4_col6 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row4_col7 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row4_col8 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row5_col0 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row5_col1 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row5_col2 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row5_col3 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row5_col4 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row5_col6 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row5_col7 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row5_col8 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row6_col0 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row6_col1 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row6_col2 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row6_col3 {
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row6_col4 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_ae3e9378_754a_11eb_bf08_210ea8513cd3row6_col5 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;

# %% [markdown]
# ## Simple linear regression with 1 parameter - col8 - that has the biggest correlation (0.688)

# %%
from sklearn.linear_model import LinearRegression

X = df[['col8']]
y = df['medianCompexValue'].values.flatten()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
reg = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# #### Evaluate the model and show results

# %%
# from sklearn.metrics import f1_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# Score on train set
print("Score on train (r-squared score):", reg.score(X_train, y_train))
print("Explained variance score:", explained_variance_score(y_train, reg.predict(X_train)))
print("MSE:", mean_squared_error(y_train, reg.predict(X_train)))
cv_score_train = cross_val_score(reg, X_train, y_train, cv=5)
print("cross val score:", cv_score_train)
print("average of cross val scores:", np.average(cv_score_train))
# Out:
# Score on train (r-squared score): 0.4738509942209922
# Explained variance score: 0.4738509942209922
# MSE: 7003180237.26786
# cross val score: [0.46612951 0.47029091 0.47862513 0.48259689 0.47108715]
# average of cross val scores: 0.47374591860634807

# %%
# from sklearn.metrics import f1_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# Score on train set
print("Score on test (r-squared score):", reg.score(X_test, y_test))
print("Explained variance score:", explained_variance_score(y_test, reg.predict(X_test)))
print("MSE:", mean_squared_error(y_test, reg.predict(X_test)))
cv_score_test = cross_val_score(reg, X_test, y_test, cv=5)
print("cross val score:", cv_score_test)
print("average of cross val scores:", np.average(cv_score_test))
# Out:
# Score on test (r-squared score): 0.4725720683367075
# Explained variance score: 0.4727089191512577
# MSE: 7028461448.540977
# cross val score: [0.47611512 0.44405205 0.44355841 0.51535857 0.47719723]
# average of cross val scores: 0.4712562764033164

# %%
df_scores = pd.DataFrame({
    'Scores': ['Scores on train', 'Scores on test'],
    'R-squared': [reg.score(X_train, y_train), reg.score(X_test, y_test)],
    'Explained variance score': [ explained_variance_score(y_train, reg.predict(X_train)),  explained_variance_score(y_test, reg.predict(X_test))],
    'MSE': [mean_squared_error(y_train, reg.predict(X_train)), mean_squared_error(y_test, reg.predict(X_test))],
    'Cross vall score average': [np.average(cv_score_train), np.average(cv_score_test)]
                          })
df_scores
# Out:
#             Scores  R-squared  Explained variance score           MSE  \
# 0  Scores on train   0.473851                  0.473851  7.003180e+09
# 1   Scores on test   0.472572                  0.472709  7.028461e+09
#
#    Cross vall score average
# 0                  0.473746
# 1                  0.471256

# %% [markdown]
# #### Make a new prediction

# %%
# Make a new prediction on the data from the first row of X_test
print("Predict price on first row of the X_test:")
print([X_test.iloc[0]])
print()
print("Real price:", y_test[0])
prediction = reg.predict([X_test.iloc[0]])[0]
print("Predicted price:", prediction)
print("Difference:", abs(prediction-y_test[0]))
print("Difference in %: ", abs(prediction-y_test[0]) / y_test[0], "%")
# Out:
# Predict price on first row of the X_test:
# [col8    1.6812
# Name: 20046, dtype: float64]
#
# Real price: 47700.0
# Predicted price: 115039.43337817646
# Difference: 67339.43337817646
# Difference in %:  1.411728163064496 %

# %% [markdown]
# ## Multiple linear regression in sklearn

# %%
from sklearn.linear_model import LinearRegression

X = df[['col1', 'col2', 'complexAge', 'totalRooms', 'totalBedrooms', 'complexInhabitants', 'apartmentsNr', 'col8']]
y = df['medianCompexValue'].values.flatten()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
reg = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# #### Evaluate the model and show results

# %%
# from sklearn.metrics import f1_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# Score on train set
print("Score on train (r-squared score):", reg.score(X_train, y_train))
print("Explained variance score:", explained_variance_score(y_train, reg.predict(X_train)))
print("MSE:", mean_squared_error(y_train, reg.predict(X_train)))
cv_score_train = cross_val_score(reg, X_train, y_train, cv=5)
print("cross val score:", cv_score_train)
print("average of cross val scores:", np.average(cv_score_train))
# Out:
# Score on train (r-squared score): 0.6366026367397183
# Explained variance score: 0.6366026367397183
# MSE: 4836913506.833794
# cross val score: [0.62100906 0.64291955 0.66183546 0.63697333 0.60746995]
# average of cross val scores: 0.6340414700668516

# %%
# from sklearn.metrics import f1_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# Score on train set
print("Score on test (r-squared score):", reg.score(X_test, y_test))
print("Explained variance score:", explained_variance_score(y_test, reg.predict(X_test)))
print("MSE:", mean_squared_error(y_test, reg.predict(X_test)))
cv_score_test = cross_val_score(reg, X_test, y_test, cv=5)
print("cross val score:", cv_score_test)
print("average of cross val scores:", np.average(cv_score_test))
# Out:
# Score on test (r-squared score): 0.6378669755308477
# Explained variance score: 0.6379102070945832
# MSE: 4825755044.29267
# cross val score: [0.63601146 0.59886899 0.62597059 0.67517998 0.64457183]
# average of cross val scores: 0.6361205685977772

# %%
df_scores = pd.DataFrame({
    'Scores': ['Scores on train', 'Scores on test'],
    'R-squared': [reg.score(X_train, y_train), reg.score(X_test, y_test)],
    'Explained variance score': [ explained_variance_score(y_train, reg.predict(X_train)),  explained_variance_score(y_test, reg.predict(X_test))],
    'MSE': [mean_squared_error(y_train, reg.predict(X_train)), mean_squared_error(y_test, reg.predict(X_test))],
    'Cross vall score average': [ np.average(cv_score_train),  np.average(cv_score_test)]
                          })
df_scores
# Out:
#             Scores  R-squared  Explained variance score           MSE  \
# 0  Scores on train   0.636603                  0.636603  4.836914e+09
# 1   Scores on test   0.637867                  0.637910  4.825755e+09
#
#    Cross vall score average
# 0                  0.634041
# 1                  0.636121

# %% [markdown]
# #### Make a new prediction

# %%
# Make a new prediction on the data from the first row of X_test
print("Predict price on first row of the X_test:")
print([X_test.iloc[0]])
print()
print("Real price:", y_test[0])
prediction = reg.predict([X_test.iloc[0]])[0]
print("Predicted price:", prediction)
print("Difference:", abs(prediction-y_test[0]))
print("Difference in %: ", abs(prediction-y_test[0]) / y_test[0], "%")
# Out:
# Predict price on first row of the X_test:
# [col1                  -119.0100
# col2                    36.0600
# complexAge              25.0000
# totalRooms            1505.0000
# totalBedrooms          367.0000
# complexInhabitants    1392.0000
# apartmentsNr           359.0000
# col8                     1.6812
# Name: 20046, dtype: float64]
#
# Real price: 47700.0
# Predicted price: 56608.13476678962
# Difference: 8908.134766789619
# Difference in %:  0.1867533494085874 %

# %% [markdown]
# ## Plot some results

# %%
Y_pred = reg.predict(X)

# %%
fig, axs = plt.subplots(ncols=4, nrows=2)
# set figure size
fig.set_figheight(15)
fig.set_figwidth(40)

i = 0
j = 0

for col in COLUMN_NAMES_FULL:
  if col!='medianCompexValue':
    a = sns.scatterplot(x=X_train[col], y=y_train, marker='s', ax=axs[i%2][j%4])
    a = sns.scatterplot(x=X_test[col], y=y_test, marker='s', ax=axs[i%2][j%4])
    a  = sns.scatterplot(x=X[col], y=Y_pred, color='red', marker='x', ax=axs[i%2][j%4])
    a.set(xlabel=col, ylabel='medianComplexValue')
    j+=1
    if j==4:
      i+=1

# %% [markdown]
# *Note: The red data is not plotted as a line - because it is multi-dimensional: there are 8 columns + 1predicted => there are 9 dimensions*

# %% [markdown]
# ## Conclusions
# - the best model achieved the r-squared score of 0.63, which means that 63% of the variability of the dependent variable is predicted from the independent variable, and the remaining 37% of the variability is still unaccounted for.
#
# - multiple linear regression, when using all the parameters that are in the dataset, obtains better results than simple linear regression (even when using the column with the biggest correlation coefficient)
#
# - because multiple linear regression uses more than 2-3 parameters, the final regression line cannot be plotted, because it is in multi dimensions (9 dimensions - 9 columns)

# %% [markdown]
# ## Save and load models

# %%
import joblib

joblib.dump(reg, 'multiple_regression_model.sav')
# Out:
# ['multiple_regression_model.sav']

# %%
import joblib

filename = 'multiple_regression_model.sav'
loaded_model = joblib.load(filename)
print(loaded_model)
# result = loaded_model.score(X_test, Y_test)
# print(result)
# Out:
# LinearRegression()

# %% [markdown]
# ## Useful resources:
#
# - https://seaborn.pydata.org/generated/seaborn.lineplot.html
# - https://seaborn.pydata.org/
# - https://seaborn.pydata.org/examples/many_pairwise_correlations.html
# - https://seaborn.pydata.org/generated/seaborn.heatmap.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
# - https://towardsdatascience.com/linear-regression-in-6-lines-of-python-5e1d0cd05b8d
# - https://scikit-learn.org/stable/modules/model_evaluation.html
# - https://machinelearningmastery.com/save-load-machine-learning-models-python-scikit-learn/
